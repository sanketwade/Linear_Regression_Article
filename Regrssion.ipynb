# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

x = 40 * np.random.random((30, 1))
y = 0.2 * x + 1.0 + np.random.normal(size=x.shape)

model = LinearRegression()
model.fit(x, y)

x_new = np.linspace(0, 50, 100)
y_new = model.predict(x_new[:, np.newaxis])

plt.figure(figsize=(5, 5))
ax = plt.axes()
ax.scatter(x, y , c ='red')
ax.plot(x_new, y_new)

ax.set_xlabel('X = Independent Variable')
ax.set_ylabel('Y = Dependent Variable')

ax.axis('tight')
plt.savefig('lin_reg')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

x = 40 * np.random.random((10, 1))
y = 0.1 * x + 1.0 + np.random.normal(size=x.shape)

model = LinearRegression()
model.fit(x, y)

x_new = np.linspace(0, 50, 100)
y_new = model.predict(x_new[:, np.newaxis])

plt.figure(figsize=(5, 5))
ax = plt.axes()
ax.scatter(x, y , c ='red')
ax.plot(x_new, y_new)

ax.set_xlabel('X = Independent Variable')
ax.set_ylabel('Y = Dependent Variable')

ax.axis('tight')
plt.savefig('lin_reg_1')
plt.show()

# %%
#Linear Regression Python Code Example
